# %%
import pytz
from datetime import datetime

data_hora_padrão = datetime.now()
timestamp_padrão = datetime.timestamp(data_hora_padrão)

# CORRETO
aware = datetime.fromtimestamp(int(timestamp_padrão))


print(aware)
# Out:
# 2023-01-11 15:01:00
