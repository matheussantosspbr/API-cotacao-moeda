# %%
from datetime import datetime
from pytz import timezone

ts = int(datetime.timestamp(datetime.now()))
myDatetime = datetime.fromtimestamp(ts, tz = timezone('America/Sao_Paulo')).strftime('%d/%m/%Y %H:%M:%S')


obj = {
        "updated_at" : myDatetime
    }

print(obj)
# Out:
# {'updated_at': '11/01/2023 22:08:21'}
